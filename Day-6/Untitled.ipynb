# %% [markdown]
# # Module

# %%
import calculation

a = calculation.add(1,2)
print(a)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import calculation
#       2 a = calculation.add(1,2)
#       3 print(a)
#
# ModuleNotFoundError: No module named 'calculation'
